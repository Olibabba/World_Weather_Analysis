# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
city_names = []
country_names = []

for x in coordinates:
    this_city = citipy.nearest_city(x[0], x[1]).city_name
    this_country = citipy.nearest_city(x[0], x[1]).country_code
    if this_city not in city_names:
        city_names.append(this_city)
        country_names.append(this_country)
len(city_names)
# Out:
# 615

# %%
url = f'https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid={weather_api_key}'

# %%
# empty list to hold weather data
city_data = []

#print log beginning
print("Beginning Data Retrieval   ")
print("---------------------------")

#create counters
record_count = 1
set_count = 1

# loop through all cities
for i, city in enumerate(city_names):
    
    # group cities in sets of 50 for logging and rest for one minute to comply with api rules
    if( i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # create url for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    #log url, record, and set numbers, and city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    #increase record
    record_count += 1
    
    try:
        #parse the json
        city_weather = requests.get(city_url).json()

        #grab the data
        country = (city_weather['sys']['country'])
        lat = (city_weather['coord']['lat'])
        lng = (city_weather['coord']['lon'])
        max_temp = (city_weather['main']['temp_max'])
        min_temp = (city_weather['main']['temp_min'])
        humidity = (city_weather['main']['humidity'])
        clouds = (city_weather['clouds']['all'])
        wind = (city_weather['wind']['speed'])

        #convert date to iso
        date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%y-%m-%d %H:%M:%S')

        #add data to city_data list
        city_data.append({'City': city.title(),
                           'Country': country,
                           "Date": date,
                           "Lat": lat,
                           "Lng": lng,
                           "Max Temp": max_temp,
                           "Min Temp": min_temp,
                           "Humidity": humidity,
                           "Cloudiness": clouds,
                           "Wind Speed": wind,})
# error handling, skip city
    except:
        print(f"City not found. Skipping...")
        pass

#data loading complete message
print("---------------------------")
print("Data Retrieval Complete    ")
print("---------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | cap malheureux
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | talnakh
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | letpadan
# Processing Record 9 of Set 1 | mezen
# Processing Record 10 of Set 1 | bougouni
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | bairiki
# Processing Record 13 of Set 1 | soe
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | bambous virieux
# Processing Record 16 of Set 1 | santa isabel do rio negro
# Processing Record 17 of Set 1 | thinadhoo
# Processing Record 18 of Set 1 | beringovskiy
# Processing Record 19 of Set 1 | prince rupert
# Processing Record 20 of Set 1 | rantauprapat
# Processing Record 21 of Set 1 | bowen
# Processing Record 22 of Set 1 | komsomolskiy
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | turukhansk
# Processing Record 27 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | ponta do sol
# Processing Record 30 of Set 1 | jiangyou
# Processing Record 31 of Set 1 | mastic
# Processing Record 32 of Set 1 | saint-joseph
# Processing Record 33 of Set 1 | tortoli
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | qaqortoq
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | ponta delgada
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | isangel
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | sistranda
# Processing Record 47 of Set 1 | kruisfontein
# Processing Record 48 of Set 1 | akyab
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 2 | governador dix-sept rosado
# Processing Record 2 of Set 2 | hasaki
# Processing Record 3 of Set 2 | ahipara
# Processing Record 4 of Set 2 | quang ngai
# Processing Record 5 of Set 2 | chapais
# Processing Record 6 of Set 2 | yar-sale
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | arraial do cabo
# Processing Record 9 of Set 2 | nyurba
# Processing Record 10 of Set 2 | mulchen
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | sur
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | daru
# Processing Record 17 of Set 2 | udachnyy
# Processing Record 18 of Set 2 | taoudenni
# Processing Record 19 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | mataura
# Processing Record 22 of Set 2 | medicine hat
# Processing Record 23 of Set 2 | hobyo
# Processing Record 24 of Set 2 | kargil
# Processing Record 25 of Set 2 | palmares do sul
# Processing Record 26 of Set 2 | coihaique
# Processing Record 27 of Set 2 | taltal
# Processing Record 28 of Set 2 | bandarbeyla
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | argayash
# Processing Record 31 of Set 2 | aswan
# Processing Record 32 of Set 2 | bathsheba
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | ostrovnoy
# Processing Record 36 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 2 | lompoc
# Processing Record 38 of Set 2 | nome
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | ust-omchug
# Processing Record 42 of Set 2 | clarence town
# Processing Record 43 of Set 2 | high level
# Processing Record 44 of Set 2 | bethel
# Processing Record 45 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 2 | haines junction
# Processing Record 47 of Set 2 | am timan
# Processing Record 48 of Set 2 | peniche
# Processing Record 49 of Set 2 | samut prakan
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | georgetown
# Processing Record 3 of Set 3 | tuktoyaktuk
# Processing Record 4 of Set 3 | san juan del sur
# Processing Record 5 of Set 3 | laiyang
# Processing Record 6 of Set 3 | takoradi
# Processing Record 7 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 3 | ovalle
# Processing Record 9 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 10 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 3 | barrow
# Processing Record 12 of Set 3 | banjar
# Processing Record 13 of Set 3 | muskegon
# Processing Record 14 of Set 3 | zaysan
# Processing Record 15 of Set 3 | san cristobal
# Processing Record 16 of Set 3 | veinticinco de mayo
# Processing Record 17 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 3 | pacific grove
# Processing Record 19 of Set 3 | fortuna
# Processing Record 20 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 3 | lima
# Processing Record 22 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 3 | bundaberg
# Processing Record 24 of Set 3 | atuona
# Processing Record 25 of Set 3 | chernyshevskiy
# Processing Record 26 of Set 3 | cayenne
# Processing Record 27 of Set 3 | sinjai
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | norman wells
# Processing Record 30 of Set 3 | hobart
# Processing Record 31 of Set 3 | shenjiamen
# Processing Record 32 of Set 3 | tunxi
# City not found. Skipping...
# Processing Record 33 of Set 3 | saint george
# Processing Record 34 of Set 3 | cabo san lucas
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | krasnogorskoye
# Processing Record 37 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | broome
# Processing Record 40 of Set 3 | san policarpo
# Processing Record 41 of Set 3 | gemena
# Processing Record 42 of Set 3 | qurayyat
# Processing Record 43 of Set 3 | houma
# Processing Record 44 of Set 3 | taksimo
# Processing Record 45 of Set 3 | nhulunbuy
# Processing Record 46 of Set 3 | clinton
# Processing Record 47 of Set 3 | mirnyy
# Processing Record 48 of Set 3 | lebu
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 4 | avera
# Processing Record 2 of Set 4 | saskylakh
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | sept-iles
# Processing Record 5 of Set 4 | padang
# Processing Record 6 of Set 4 | yulara
# Processing Record 7 of Set 4 | seoul
# Processing Record 8 of Set 4 | rio grande
# Processing Record 9 of Set 4 | candido mendes
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | lagoa
# Processing Record 12 of Set 4 | khatanga
# Processing Record 13 of Set 4 | mitsamiouli
# Processing Record 14 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 4 | hilo
# Processing Record 16 of Set 4 | bengkulu
# Processing Record 17 of Set 4 | sisimiut
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | clonakilty
# Processing Record 20 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 4 | amapa
# Processing Record 22 of Set 4 | havre-saint-pierre
# Processing Record 23 of Set 4 | sulangan
# Processing Record 24 of Set 4 | pakruojis
# Processing Record 25 of Set 4 | arman
# Processing Record 26 of Set 4 | porto novo
# Processing Record 27 of Set 4 | lavrentiya
# Processing Record 28 of Set 4 | raduzhnyy
# Processing Record 29 of Set 4 | san francisco
# Processing Record 30 of Set 4 | ouargaye
# Processing Record 31 of Set 4 | torbay
# Processing Record 32 of Set 4 | zacualpan
# Processing Record 33 of Set 4 | ayan
# Processing Record 34 of Set 4 | antalaha
# Processing Record 35 of Set 4 | kaitangata
# Processing Record 36 of Set 4 | cradock
# Processing Record 37 of Set 4 | pevek
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | burica
# City not found. Skipping...
# Processing Record 40 of Set 4 | waitati
# Processing Record 41 of Set 4 | hami
# Processing Record 42 of Set 4 | thompson
# Processing Record 43 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 4 | myaundzha
# Processing Record 45 of Set 4 | inhambane
# Processing Record 46 of Set 4 | yenagoa
# Processing Record 47 of Set 4 | hermanus
# Processing Record 48 of Set 4 | longyearbyen
# Processing Record 49 of Set 4 | teguise
# Processing Record 50 of Set 4 | lawrenceburg
# Processing Record 1 of Set 5 | esqueda
# Processing Record 2 of Set 5 | klang
# Processing Record 3 of Set 5 | wanning
# Processing Record 4 of Set 5 | saint-augustin
# Processing Record 5 of Set 5 | coahuayana
# Processing Record 6 of Set 5 | namie
# Processing Record 7 of Set 5 | fairbanks
# Processing Record 8 of Set 5 | alofi
# Processing Record 9 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 5 | guerrero negro
# Processing Record 11 of Set 5 | severo-kurilsk
# Processing Record 12 of Set 5 | chicama
# Processing Record 13 of Set 5 | port jervis
# Processing Record 14 of Set 5 | pangnirtung
# Processing Record 15 of Set 5 | tasiilaq
# Processing Record 16 of Set 5 | sumbe
# Processing Record 17 of Set 5 | cidreira
# Processing Record 18 of Set 5 | los llanos de aridane
# Processing Record 19 of Set 5 | ambon
# Processing Record 20 of Set 5 | salinopolis
# Processing Record 21 of Set 5 | marawi
# Processing Record 22 of Set 5 | cintalapa
# Processing Record 23 of Set 5 | castro
# Processing Record 24 of Set 5 | upernavik
# Processing Record 25 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 5 | san andres
# Processing Record 27 of Set 5 | sitka
# Processing Record 28 of Set 5 | vigrestad
# Processing Record 29 of Set 5 | bridgetown
# Processing Record 30 of Set 5 | linfen
# Processing Record 31 of Set 5 | palu
# Processing Record 32 of Set 5 | simao
# Processing Record 33 of Set 5 | portland
# Processing Record 34 of Set 5 | namatanai
# Processing Record 35 of Set 5 | poronaysk
# Processing Record 36 of Set 5 | asau
# Processing Record 37 of Set 5 | yumen
# Processing Record 38 of Set 5 | olinda
# Processing Record 39 of Set 5 | labelle
# Processing Record 40 of Set 5 | caravelas
# Processing Record 41 of Set 5 | weihai
# Processing Record 42 of Set 5 | provideniya
# Processing Record 43 of Set 5 | shestakovo
# Processing Record 44 of Set 5 | mujiayingzi
# Processing Record 45 of Set 5 | tias
# Processing Record 46 of Set 5 | calama
# Processing Record 47 of Set 5 | bunia
# Processing Record 48 of Set 5 | toktogul
# Processing Record 49 of Set 5 | ngunguru
# Processing Record 50 of Set 5 | beni
# Processing Record 1 of Set 6 | tura
# Processing Record 2 of Set 6 | nouadhibou
# Processing Record 3 of Set 6 | jaciara
# Processing Record 4 of Set 6 | osoyoos
# Processing Record 5 of Set 6 | baghdad
# Processing Record 6 of Set 6 | vostok
# Processing Record 7 of Set 6 | tiarei
# Processing Record 8 of Set 6 | clyde river
# Processing Record 9 of Set 6 | hay river
# Processing Record 10 of Set 6 | ahuimanu
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | port lincoln
# Processing Record 13 of Set 6 | ca mau
# Processing Record 14 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 6 | guaca
# Processing Record 16 of Set 6 | belaya gora
# Processing Record 17 of Set 6 | quballat
# Processing Record 18 of Set 6 | amuntai
# Processing Record 19 of Set 6 | buyukcavuslu
# Processing Record 20 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 21 of Set 6 | san quintin
# Processing Record 22 of Set 6 | havelock
# Processing Record 23 of Set 6 | kaeo
# Processing Record 24 of Set 6 | aykhal
# Processing Record 25 of Set 6 | camacha
# Processing Record 26 of Set 6 | aktau
# Processing Record 27 of Set 6 | dunedin
# Processing Record 28 of Set 6 | katherine
# Processing Record 29 of Set 6 | moree
# Processing Record 30 of Set 6 | benicarlo
# Processing Record 31 of Set 6 | xuddur
# Processing Record 32 of Set 6 | tiksi
# Processing Record 33 of Set 6 | vila velha
# Processing Record 34 of Set 6 | khorixas
# Processing Record 35 of Set 6 | nola
# Processing Record 36 of Set 6 | zhigansk
# Processing Record 37 of Set 6 | broken hill
# Processing Record 38 of Set 6 | banfora
# Processing Record 39 of Set 6 | hohhot
# Processing Record 40 of Set 6 | bilma
# Processing Record 41 of Set 6 | airai
# Processing Record 42 of Set 6 | korla
# Processing Record 43 of Set 6 | forbes
# Processing Record 44 of Set 6 | la ronge
# Processing Record 45 of Set 6 | chokurdakh
# Processing Record 46 of Set 6 | blackwater
# Processing Record 47 of Set 6 | izumo
# Processing Record 48 of Set 6 | manokwari
# Processing Record 49 of Set 6 | banda aceh
# Processing Record 50 of Set 6 | leningradskiy
# Processing Record 1 of Set 7 | haimen
# Processing Record 2 of Set 7 | mendi
# Processing Record 3 of Set 7 | pryazha
# Processing Record 4 of Set 7 | kemijarvi
# Processing Record 5 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 7 | alice springs
# Processing Record 7 of Set 7 | chabua
# Processing Record 8 of Set 7 | diffa
# Processing Record 9 of Set 7 | cherskiy
# Processing Record 10 of Set 7 | anshun
# Processing Record 11 of Set 7 | husavik
# Processing Record 12 of Set 7 | kuito
# Processing Record 13 of Set 7 | talara
# Processing Record 14 of Set 7 | westport
# Processing Record 15 of Set 7 | vanimo
# Processing Record 16 of Set 7 | te anau
# Processing Record 17 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 18 of Set 7 | tautira
# Processing Record 19 of Set 7 | waipawa
# Processing Record 20 of Set 7 | kyshtovka
# Processing Record 21 of Set 7 | okha
# Processing Record 22 of Set 7 | miri
# Processing Record 23 of Set 7 | tawang
# Processing Record 24 of Set 7 | carballo
# Processing Record 25 of Set 7 | chishtian mandi
# Processing Record 26 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 7 | huarmey
# Processing Record 28 of Set 7 | ancud
# Processing Record 29 of Set 7 | chilca
# Processing Record 30 of Set 7 | coquimbo
# Processing Record 31 of Set 7 | notodden
# Processing Record 32 of Set 7 | ausa
# Processing Record 33 of Set 7 | novyy urengoy
# Processing Record 34 of Set 7 | sao lourenco do sul
# Processing Record 35 of Set 7 | kopayhorod
# Processing Record 36 of Set 7 | melegnano
# Processing Record 37 of Set 7 | marzuq
# Processing Record 38 of Set 7 | shimoda
# Processing Record 39 of Set 7 | bathurst
# Processing Record 40 of Set 7 | el guapinol
# Processing Record 41 of Set 7 | mogok
# Processing Record 42 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 43 of Set 7 | salalah
# Processing Record 44 of Set 7 | kholm
# Processing Record 45 of Set 7 | businga
# Processing Record 46 of Set 7 | vestmanna
# Processing Record 47 of Set 7 | wolfville
# Processing Record 48 of Set 7 | honiara
# Processing Record 49 of Set 7 | bulgan
# Processing Record 50 of Set 7 | horodyshche
# Processing Record 1 of Set 8 | mayo
# Processing Record 2 of Set 8 | kerteh
# City not found. Skipping...
# Processing Record 3 of Set 8 | acapulco
# Processing Record 4 of Set 8 | naze
# Processing Record 5 of Set 8 | karlskrona
# Processing Record 6 of Set 8 | sorland
# Processing Record 7 of Set 8 | pasighat
# Processing Record 8 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 8 | kloulklubed
# Processing Record 10 of Set 8 | coolum beach
# Processing Record 11 of Set 8 | hit
# Processing Record 12 of Set 8 | west wendover
# Processing Record 13 of Set 8 | eslov
# Processing Record 14 of Set 8 | kailua
# Processing Record 15 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 8 | malindi
# Processing Record 17 of Set 8 | srednekolymsk
# Processing Record 18 of Set 8 | scarborough
# Processing Record 19 of Set 8 | vestmannaeyjar
# Processing Record 20 of Set 8 | usogorsk
# Processing Record 21 of Set 8 | dukat
# Processing Record 22 of Set 8 | kamenka
# Processing Record 23 of Set 8 | wajima
# Processing Record 24 of Set 8 | pokhara
# Processing Record 25 of Set 8 | victoria
# Processing Record 26 of Set 8 | hofn
# Processing Record 27 of Set 8 | palana
# Processing Record 28 of Set 8 | stoyba
# City not found. Skipping...
# Processing Record 29 of Set 8 | zhicheng
# Processing Record 30 of Set 8 | azanka
# Processing Record 31 of Set 8 | laerdalsoyri
# Processing Record 32 of Set 8 | berezovyy
# Processing Record 33 of Set 8 | ugoofaaru
# Processing Record 34 of Set 8 | kulob
# Processing Record 35 of Set 8 | akdepe
# Processing Record 36 of Set 8 | ternate
# Processing Record 37 of Set 8 | doka
# Processing Record 38 of Set 8 | sangar
# Processing Record 39 of Set 8 | kazachinskoye
# Processing Record 40 of Set 8 | marienburg
# Processing Record 41 of Set 8 | puerto madryn
# Processing Record 42 of Set 8 | sao filipe
# Processing Record 43 of Set 8 | jiuquan
# Processing Record 44 of Set 8 | pisco
# Processing Record 45 of Set 8 | jiexiu
# Processing Record 46 of Set 8 | pasni
# Processing Record 47 of Set 8 | ust-tsilma
# Processing Record 48 of Set 8 | stykkisholmur
# Processing Record 49 of Set 8 | cam ranh
# Processing Record 50 of Set 8 | okhotsk
# Processing Record 1 of Set 9 | nipawin
# Processing Record 2 of Set 9 | basco
# Processing Record 3 of Set 9 | zalesovo
# Processing Record 4 of Set 9 | nago
# Processing Record 5 of Set 9 | bloemfontein
# Processing Record 6 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 9 | dingle
# Processing Record 8 of Set 9 | makat
# Processing Record 9 of Set 9 | muscat
# Processing Record 10 of Set 9 | rosario oeste
# Processing Record 11 of Set 9 | zyryanka
# Processing Record 12 of Set 9 | bakchar
# Processing Record 13 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 9 | morros
# Processing Record 16 of Set 9 | chake chake
# Processing Record 17 of Set 9 | kabwe
# Processing Record 18 of Set 9 | tuim
# Processing Record 19 of Set 9 | krasnoselkup
# Processing Record 20 of Set 9 | seydi
# Processing Record 21 of Set 9 | maradi
# Processing Record 22 of Set 9 | antofagasta
# Processing Record 23 of Set 9 | qandala
# Processing Record 24 of Set 9 | luoyang
# Processing Record 25 of Set 9 | sinegorye
# Processing Record 26 of Set 9 | trairi
# Processing Record 27 of Set 9 | dhule
# Processing Record 28 of Set 9 | boyolangu
# Processing Record 29 of Set 9 | moranbah
# Processing Record 30 of Set 9 | skibbereen
# Processing Record 31 of Set 9 | coari
# Processing Record 32 of Set 9 | ban nahin
# Processing Record 33 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 9 | mehriz
# Processing Record 35 of Set 9 | kenitra
# Processing Record 36 of Set 9 | springdale
# Processing Record 37 of Set 9 | mandan
# Processing Record 38 of Set 9 | mutis
# Processing Record 39 of Set 9 | rawson
# Processing Record 40 of Set 9 | kodinsk
# Processing Record 41 of Set 9 | tucuma
# Processing Record 42 of Set 9 | malakal
# Processing Record 43 of Set 9 | luderitz
# Processing Record 44 of Set 9 | katima mulilo
# Processing Record 45 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 9 | nichinan
# Processing Record 47 of Set 9 | strezhevoy
# Processing Record 48 of Set 9 | kautokeino
# Processing Record 49 of Set 9 | bria
# Processing Record 50 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 10 | garissa
# Processing Record 2 of Set 10 | meulaboh
# Processing Record 3 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 10 | tyukhtet
# Processing Record 5 of Set 10 | san patricio
# Processing Record 6 of Set 10 | siniscola
# Processing Record 7 of Set 10 | fare
# Processing Record 8 of Set 10 | ferme-neuve
# Processing Record 9 of Set 10 | yate
# Processing Record 10 of Set 10 | sosnovo-ozerskoye
# Processing Record 11 of Set 10 | kununurra
# Processing Record 12 of Set 10 | humaita
# Processing Record 13 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 10 | chiquinquira
# Processing Record 15 of Set 10 | biak
# Processing Record 16 of Set 10 | korem
# Processing Record 17 of Set 10 | amancio
# City not found. Skipping...
# Processing Record 18 of Set 10 | rocha
# Processing Record 19 of Set 10 | nagorsk
# Processing Record 20 of Set 10 | inuvik
# Processing Record 21 of Set 10 | aldan
# Processing Record 22 of Set 10 | ulaangom
# Processing Record 23 of Set 10 | kano
# Processing Record 24 of Set 10 | klaksvik
# Processing Record 25 of Set 10 | darhan
# Processing Record 26 of Set 10 | chikwawa
# Processing Record 27 of Set 10 | teluk nibung
# Processing Record 28 of Set 10 | arrecife
# Processing Record 29 of Set 10 | damietta
# Processing Record 30 of Set 10 | khandyga
# Processing Record 31 of Set 10 | pitimbu
# Processing Record 32 of Set 10 | lashio
# Processing Record 33 of Set 10 | axim
# Processing Record 34 of Set 10 | port augusta
# Processing Record 35 of Set 10 | curup
# Processing Record 36 of Set 10 | duz
# City not found. Skipping...
# Processing Record 37 of Set 10 | batemans bay
# Processing Record 38 of Set 10 | richards bay
# Processing Record 39 of Set 10 | alencon
# Processing Record 40 of Set 10 | songjianghe
# Processing Record 41 of Set 10 | mount gambier
# Processing Record 42 of Set 10 | alanya
# Processing Record 43 of Set 10 | pulandian
# Processing Record 44 of Set 10 | tikhvin
# Processing Record 45 of Set 10 | sabang
# Processing Record 46 of Set 10 | holalkere
# Processing Record 47 of Set 10 | yusva
# City not found. Skipping...
# Processing Record 48 of Set 10 | plettenberg bay
# Processing Record 49 of Set 10 | leh
# Processing Record 50 of Set 10 | bud
# Processing Record 1 of Set 11 | abu dhabi
# Processing Record 2 of Set 11 | shenzhen
# Processing Record 3 of Set 11 | mahebourg
# Processing Record 4 of Set 11 | berlevag
# Processing Record 5 of Set 11 | faya
# Processing Record 6 of Set 11 | muros
# Processing Record 7 of Set 11 | pinsk
# Processing Record 8 of Set 11 | sussex
# Processing Record 9 of Set 11 | suraabad
# Processing Record 10 of Set 11 | palmer
# Processing Record 11 of Set 11 | riyaq
# City not found. Skipping...
# Processing Record 12 of Set 11 | burnie
# Processing Record 13 of Set 11 | grindavik
# Processing Record 14 of Set 11 | noumea
# Processing Record 15 of Set 11 | rio gallegos
# Processing Record 16 of Set 11 | ilulissat
# Processing Record 17 of Set 11 | nabire
# Processing Record 18 of Set 11 | nelson bay
# Processing Record 19 of Set 11 | santa cruz del sur
# Processing Record 20 of Set 11 | pyinmana
# Processing Record 21 of Set 11 | samarai
# Processing Record 22 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 23 of Set 11 | port hawkesbury
# Processing Record 24 of Set 11 | sanmihaiu roman
# Processing Record 25 of Set 11 | hamilton
# Processing Record 26 of Set 11 | yakeshi
# Processing Record 27 of Set 11 | mnogovershinnyy
# Processing Record 28 of Set 11 | portales
# Processing Record 29 of Set 11 | weiden
# Processing Record 30 of Set 11 | bilibino
# Processing Record 31 of Set 11 | itoman
# Processing Record 32 of Set 11 | la grande
# Processing Record 33 of Set 11 | laguna
# Processing Record 34 of Set 11 | nanchang
# Processing Record 35 of Set 11 | tommot
# Processing Record 36 of Set 11 | chiapa
# Processing Record 37 of Set 11 | cumberland
# Processing Record 38 of Set 11 | junagarh
# Processing Record 39 of Set 11 | tamandare
# Processing Record 40 of Set 11 | tual
# Processing Record 41 of Set 11 | lebedinyy
# Processing Record 42 of Set 11 | gat
# Processing Record 43 of Set 11 | temiscaming
# Processing Record 44 of Set 11 | healdsburg
# Processing Record 45 of Set 11 | narsaq
# Processing Record 46 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 47 of Set 11 | tabou
# Processing Record 48 of Set 11 | saquena
# Processing Record 49 of Set 11 | henties bay
# Processing Record 50 of Set 11 | villarrica
# Processing Record 1 of Set 12 | behat
# Processing Record 2 of Set 12 | jumla
# Processing Record 3 of Set 12 | wegorzewo
# Processing Record 4 of Set 12 | college
# Processing Record 5 of Set 12 | turinskaya sloboda
# Processing Record 6 of Set 12 | colombia
# Processing Record 7 of Set 12 | manavalakurichi
# Processing Record 8 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 9 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 10 of Set 12 | mattawa
# Processing Record 11 of Set 12 | puerto carreno
# Processing Record 12 of Set 12 | lar
# Processing Record 13 of Set 12 | zhanaozen
# Processing Record 14 of Set 12 | kita
# Processing Record 15 of Set 12 | paraiba do sul
# Processing Record 16 of Set 12 | monrovia
# Processing Record 17 of Set 12 | pohorelice
# Processing Record 18 of Set 12 | fort nelson
# Processing Record 19 of Set 12 | verkhoyansk
# Processing Record 20 of Set 12 | vila franca do campo
# Processing Record 21 of Set 12 | brae
# Processing Record 22 of Set 12 | canazas
# Processing Record 23 of Set 12 | tadine
# Processing Record 24 of Set 12 | xinzhou
# Processing Record 25 of Set 12 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 26 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 27 of Set 12 | sakakah
# Processing Record 28 of Set 12 | goderich
# Processing Record 29 of Set 12 | kandrian
# Processing Record 30 of Set 12 | juneau
# Processing Record 31 of Set 12 | egersund
# Processing Record 32 of Set 12 | emerald
# Processing Record 33 of Set 12 | kizner
# Processing Record 34 of Set 12 | fairlie
# Processing Record 35 of Set 12 | kysyl-syr
# Processing Record 36 of Set 12 | the valley
# Processing Record 37 of Set 12 | dombarovskiy
# Processing Record 38 of Set 12 | bosaso
# Processing Record 39 of Set 12 | port hardy
# Processing Record 40 of Set 12 | muhos
# Processing Record 41 of Set 12 | robertsport
# Processing Record 42 of Set 12 | sainte-thecle
# Processing Record 43 of Set 12 | parana
# Processing Record 44 of Set 12 | tuatapere
# Processing Record 45 of Set 12 | lata
# Processing Record 46 of Set 12 | agropoli
# Processing Record 47 of Set 12 | eyrarbakki
# Processing Record 48 of Set 12 | aloleng
# Processing Record 49 of Set 12 | bauchi
# Processing Record 50 of Set 12 | altay
# Processing Record 1 of Set 13 | chabahar
# Processing Record 2 of Set 13 | riyadh
# Processing Record 3 of Set 13 | tzucacab
# Processing Record 4 of Set 13 | dawei
# Processing Record 5 of Set 13 | kedrovyy
# Processing Record 6 of Set 13 | buariki
# City not found. Skipping...
# Processing Record 7 of Set 13 | abu kamal
# Processing Record 8 of Set 13 | verkhniy mamon
# Processing Record 9 of Set 13 | geraldton
# Processing Record 10 of Set 13 | herat
# Processing Record 11 of Set 13 | wahiawa
# Processing Record 12 of Set 13 | lagunas
# Processing Record 13 of Set 13 | kudahuvadhoo
# Processing Record 14 of Set 13 | shakawe
# Processing Record 15 of Set 13 | ostrzeszow
# ---------------------------
# Data Retrieval Complete
# ---------------------------

# %%
len(city_data)
# Out:
# 563

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country               Date      Lat       Lng  Max Temp  \
# 0  Cap Malheureux      MU  22-04-26 03:55:44 -19.9842   57.6142     75.47
# 1  Ribeira Grande      PT  22-04-26 03:55:45  38.5167  -28.7000     59.18
# 2         Ushuaia      AR  22-04-26 03:55:11 -54.8000  -68.3000     40.66
# 3         Talnakh      RU  22-04-26 03:55:46  69.4865   88.3972      9.21
# 4   Mar Del Plata      AR  22-04-26 03:55:47 -38.0023  -57.5575     60.87
# 5       Busselton      AU  22-04-26 03:53:14 -33.6500  115.3333     68.02
# 6        Letpadan      MM  22-04-26 03:55:47  17.7833   95.7500     97.41
# 7           Mezen      RU  22-04-26 03:55:48  65.8522   44.2400     33.64
# 8        Bougouni      ML  22-04-26 03:55:48  11.4170   -7.4790     80.78
# 9    Punta Arenas      CL  22-04-26 03:53:15 -53.1500  -70.9167     37.51
#
#    Min Temp  Humidity  Cloudiness  Wind Speed
# 0     75.47        78          21        3.00
# 1     59.18        71          68        9.37
# 2     40.66        70          40       17.27
# 3      9.21        91         100        7.58
# 4     46.42        81           6        8.01
# 5     68.02        51          45       15.57
# 6     97.41        38           8        6.89
# 7     33.64        99         100        5.01
# 8     80.78        19          76        3.71
# 9     37.11        65           0       10.36

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
